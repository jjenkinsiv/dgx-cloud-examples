# %% [markdown]
# # S3 Data Download into Lepton Local Storage
#
# This notebook demonstrates how to download data from an external S3 bucket to mounted storage on a DGX Cloud Lepton Dev Pod. It uses a publicly available dataset for global fishery statistics as an example of loading a CSV dataset into a pandas DataFrame. You can adapt this notebook to work with your own S3 buckets for transferring data to and from the Dev Pod.
#
# <div class="alert alert-block alert-info">
# <b>Note: </b>The license and terms of use for this sample dataset can be found <a href=https://registry.opendata.aws/sau-global-fisheries-catch-data/>here</a>.
# </div>

# %% [markdown]
# ### Requirements
#
# -  Container: An NGC notebook container image such as `nvcr.io/nvidia/pytorch:24.10-py3` or later
# -  Packages: s3fs Python package installed
# -  GPUs: An NVIDIA Ampere or greater class GPU for cuDF acceleration (for example, A100)
# -  Storage: Follow the instructions below for storage setup

# %% [markdown]
# ### Storage Mount Setup

# %% [markdown]
# Follow the instructions in the __[Storage guide](https://docs.nvidia.com/dgx-cloud/lepton/features/utilities/storage/)__ to setup either Node Local or Static NFS volumes in DGX Cloud Lepton. You will mount the filesystem in the container at `/mnt/s3`.
#
# <div class="alert alert-block alert-info">
# <b>Note: </b>The prescribed NGC image happens to be built with the root user. If your image user is non-root, for example having a UID/GID of 1001, there are some options in Lepton for ensuring the storage mount is writable:
#
# 1. Launch the Dev Pod using the `root` override option for custom images under `Run As`.
# 2. Create a Node Local storage mount using a world-writable location on the node such as `/tmp`. Using `/tmp` has the caveat that the files there may be deleted after a reboot. So, it's important to also use S3 to periodically store your data.
#
# </div>

# %% [markdown]
# ### Install s3fs

# %% [markdown]
# Install the __[s3fs](https://s3fs.readthedocs.io/en/latest/)__ pip package to enable S3 file system operations.

# %%
# !pip install s3fs

# %% [markdown]
# ### Import pandas (Optionally with cuDF GPU Acceleration)

# %% [markdown]
# To run the GPU-accelerated version of __[pandas](https://pandas.pydata.org/docs/index.html)__, load the __[cuDF](https://docs.rapids.ai/api/cudf/stable/)__ extension.

# %%
# %load_ext cudf.pandas

# %% [markdown]
# Import pandas in its own cell to make sure the previous load extension step was completed by the kernel.

# %%
import pandas as pd

# %% [markdown]
# ### Anonymous S3 Access

# %% [markdown]
# Import the s3fs package and then, load a publicly available S3 dataset for yearly fishery statistics from around the globe. No credentials, access keys, secrets, or account are required in this case (anonymous access).

# %%
import s3fs

# %%
local_path = '/mnt/s3/rfmo_12.csv'
bucket_path = 's3://fisheries-catch-data/global-catch-data/csv/rfmo_12.csv'
s3 = s3fs.S3FileSystem(anon=True)

# %% [markdown]
# ### Options for Connecting to S3

# %% [markdown]
# If you need to access a private S3 bucket, you can provide your access key and secret directly.

# %%
# s3 = s3fs.S3FileSystem(
#      key='YOUR_ACCESS_KEY...',
#      secret='YOUR_ACCESS_SECRET...'
#    )

# %% [markdown]
# s3fs can also detect and use appropriate environment variables if they have been set for the key and secret.

# %%
# export FSSPEC_S3_KEY='YOUR_ACCESS_KEY...'
# export FSSPEC_S3_SECRET='YOUR_ACCESS_SECRET...'
# s3 = s3fs.S3FileSystem()

# %% [markdown]
# Credentials can also be detected and used by the underlying boto credential helper from client_kwargs, environment variables, config files, or an EC2 IAM server.

# %%
# s3 = s3fs.S3FileSystem(anon=False)

# %% [markdown]
# Finally, s3fs is compatible with non-AWS object storage such as MinIO. In this case, specify the URL of the MinIO endpoint.

# %%
# s3 = s3fs.S3FileSystem(
#      endpoint_url='https://non.aws.such.as.minio...'
#   )

# %% [markdown]
# ### Download a Dataset from S3

# %%
s3.download(bucket_path, local_path)

# %% [markdown]
# Perform a cursory check that we have downloaded the dataset.

# %%
# !ls -lh /mnt/s3/*.csv

# %% [markdown]
# ### Load the Dataset into a pandas DataFrame

# %% [markdown]
# Read the downloaded CSV file into a pandas DataFrame.

# %%
df = pd.read_csv(local_path)

# %% [markdown]
# ### Work with the DataFrame

# %% [markdown]
# Check the number of rows in the DataFrame.

# %%
len(df)

# %% [markdown]
# Examine the original datatypes used for each column.

# %%
df.dtypes

# %% [markdown]
# Generally describe the original dataset.

# %%
df.describe(include='object')

# %% [markdown]
# Look at the first 5 rows of the DataFrame.

# %%
df.head()

# %% [markdown]
# Look at the last 5 rows of the DataFrame.

# %%
df.tail()

# %% [markdown]
# Count the top 15 different instances of fishing gear in the dataset. Profile the GPU usage (which may be minimal).

# %%
# %%cudf.pandas.profile
# df["gear_name"].value_counts().head(15)

# %% [markdown]
# Convert some of the columns from object to numeric or date types.

# %%
df['year'] = pd.to_datetime(df['year'])
df['catch_sum'] = pd.to_numeric(df['catch_sum'])
df['real_value'] = pd.to_numeric(df['real_value'])

# %% [markdown]
# Check the datatypes again.

# %%
df.dtypes

# %% [markdown]
# Collect the last 5 years of the dataset.

# %%
years = df['year'].unique()[-5:]

# %% [markdown]
# Create a new DataFrame from the top 15 countries in the dataset with the largest total catch in metric tonnes between 2014 and 2018.

# %%
top_fisheries_by_catch = df[(df['year'] >= years[0]) & (df['year'] <= years[4])].groupby(['fishing_entity'], as_index = False)[['catch_sum']].sum().copy().sort_values(by='catch_sum',ascending=False).head(15)

# %% [markdown]
# Plot the result as a horizontal bar chart.

# %%
import matplotlib.pyplot as plt

# %%
colors = ['red', 'green', 'blue', 'purple', 'orange','yellow']
top_fisheries_by_catch.plot(x='fishing_entity',y='catch_sum',kind='barh',color=colors,legend=False)
plt.title('Top 15 Fishing Catch by Country/Region 2014-2018')
plt.xlabel('Metric Tonnes')
plt.ylabel('Countries/Regions')
plt.show()

# %% [markdown]
# This completes the notebook example.
